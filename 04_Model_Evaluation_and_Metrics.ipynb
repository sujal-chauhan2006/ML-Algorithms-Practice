# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
df = pd.read_csv('/content/placement(SLR).csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
sns.scatterplot(x='cgpa',y='package',data=df)
plt.xlabel('cgpa')
plt.ylabel('package(LPA)')
plt.title('cgpa vs package ')
# Out:
# Text(0.5, 1.0, 'cgpa vs package ')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#      cgpa
# 79   7.18
# 197  7.21
# 38   8.62
# 24   6.53
# 122  5.12

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
sns.scatterplot(df,x = 'cgpa',y = 'package')
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('package(LPA)')
plt.title('cgpa vs package with regression line')
# Out:
# Text(0.5, 1.0, 'cgpa vs package with regression line')

# %%
lr.predict(x_test)
# Out:
# array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#        3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#        1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#        3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#        2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#        2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#        3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#        3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298])

# %%
y_test.values
# Out:
# array([2.79, 3.23, 3.26, 3.04, 3.34, 4.21, 2.94, 2.87, 2.99, 3.58, 1.63,
#        2.08, 4.08, 2.21, 3.47, 3.64, 2.74, 3.08, 2.17, 2.99, 2.31, 2.35,
#        3.4 , 3.08, 3.81, 2.19, 1.53, 2.89, 3.16, 2.48, 3.51, 2.98, 3.39,
#        3.28, 2.73, 3.74, 2.6 , 3.13, 3.82, 3.15])

# %%
print('MAE :',mean_absolute_error(y_test,y_pred))
print('MSE :',mean_squared_error(y_test,y_pred))
print('RMSE :',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MAE : 0.23150985393278373
# MSE : 0.08417638361329656
# RMSE : 0.2901316659954521

# %%
print('R2 Score :',r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# For adjested R2 Score
print('Adjusted R2_score :',1-((1-r2)*(40-1) / (40-1-1)))
# Out:
# R2 Score : 0.7730984312051673
# Adjusted R2_score : 0.7671273372895138

# %%
new_df = df.copy()
new_df['random_feature'] = np.random.random(200)

# %%
new_df.head()
# Out:
#    cgpa  package  random_feature
# 0  6.89     3.26        0.949855
# 1  5.12     1.98        0.329131
# 2  7.82     3.25        0.306600
# 3  7.42     3.67        0.116201
# 4  6.94     3.57        0.446564

# %%
sns.scatterplot(new_df,x='random_feature',y='package')
plt.xlabel('random_feature')
plt.ylabel('package(LPA)')
plt.title('random_feature vs package')
# Out:
# Text(0.5, 1.0, 'random_feature vs package')

# %%
x = new_df.loc[:,['cgpa','random_feature']]
y = new_df.loc[:,['package']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#      cgpa  random_feature
# 79   7.18        0.874227
# 197  7.21        0.392050
# 38   8.62        0.388303
# 24   6.53        0.325179
# 122  5.12        0.674330

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print('R2 Score :',r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# For adjested R2 Score
print('Adjusted R2_score :',1-((1-r2)*(40-1) / (40-1-2)))
# Out:
# R2 Score : 0.7735584388415976
# Adjusted R2_score : 0.7613183544546569

# %%
new_df2 = df.copy()
new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.head()
# Out:
#    cgpa    iq  package
# 0  6.89  2.16     3.26
# 1  5.12  1.88     1.98
# 2  7.82  2.55     3.25
# 3  7.42  2.87     3.67
# 4  6.94  3.97     3.57

# %%
sns.scatterplot(new_df2,x='iq',y='package')
plt.xlabel('iq')
plt.ylabel('package(LPA)')
plt.title('iq vs package')
# Out:
# Text(0.5, 1.0, 'iq vs package')

# %%
x = new_df2.loc[:,['cgpa','iq']]
y = new_df2.loc[:,['package']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print('R2 Score :',r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# For adjested R2 Score
print('Adjusted R2_score :',1-((1-r2)*(40-1) / (40-1-2)))
# Out:
# R2 Score : 0.8327371090079331
# Adjusted R2_score : 0.8236958716570105
