# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/placement(SLR).csv')

# %%
df.shape
# Out:
# (200, 2)

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
sns.scatterplot(x='cgpa',y='package',data = df)
plt.xlabel('CGPA')
plt.xlabel('Packege')
# Out:
# Text(0.5, 0, 'Packege')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(
                                x,y,test_size=0.2,random_state=42
                                    )

# %%
x_train.shape
# Out:
# (160, 1)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
r2_score(y_pred,y_test)
# Out:
# 0.733797338294438

# %%
x_test.head()
# Out:
#      cgpa
# 95   6.63
# 15   7.25
# 30   7.36
# 158  5.95
# 128  7.93

# %%
y_test.head()
# Out:
# 95     2.79
# 15     3.23
# 30     3.26
# 158    3.04
# 128    3.34
# Name: package, dtype: float64

# %%
lr.predict(x_test.iloc[1].values.reshape(1,1))
# Out:
# array([3.13635249])

# %%
sns.scatterplot(x='cgpa',y='package',data = df)
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.xlabel('Packege')
# Out:
# Text(0.5, 0, 'Packege')

# %% [markdown]
# # Behind the algorithem

# %%
# formula is  : y = mx + b

# m is angle that make the red line
# x is input number
# b is distnce between line lowest point and x_axis
# y is output Number

# %%
# find m
m = lr.coef_

# %%
# find b
b = lr.intercept_

# %%
# Some examples
# x = 5.95

m * 5.95 + b

# that how maqchine work behind the scene
# Out:
# array([2.38981908])

# %%
from sklearn.linear_model import SGDRegressor
sg = SGDRegressor()
sg.fit(x_train,y_train)
# Out:
# SGDRegressor()

# %%
y_pred = sg.predict(x_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.4868564618635457

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 0.23804065214590783
