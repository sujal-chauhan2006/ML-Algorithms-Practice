# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# %%
x,y = load_diabetes(return_X_y=True)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=4)

# %%
reg = SGDRegressor(
    penalty='l2',
    max_iter=200,
    learning_rate='constant',
    alpha=0.001
)

# %%
reg.fit(x_train,y_train)
# Out:
# SGDRegressor(alpha=0.001, learning_rate='constant', max_iter=200)

# %%
y_pred = reg.predict(x_test)
print('R2_score :-',r2_score(y_test,y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2_score :- 0.4388827547466956
# [  55.83864172 -104.03285657  322.44474968  239.93074067   16.56648028
#   -29.07831307 -161.92046968  141.37709964  291.91165439  114.96009569]
# [151.0961669]

# %%
reg2 = Ridge(alpha=0.001,max_iter=500,solver='sparse_cg')

# %%
reg2.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.001, max_iter=500, solver='sparse_cg')

# %%
y_pred = reg2.predict(x_test)
print('R2_score :-',r2_score(y_test,y_pred))
print(reg2.coef_)
print(reg2.intercept_)
# Out:
# R2_score :- 0.46250101619914563
# [  34.52192544 -290.84084076  482.40181344  368.0678662  -852.44873179
#   501.59160336  180.11115788  270.76333979  759.73534372   37.4913546 ]
# 151.10198517439466

# %%
class MeraRidgeGD:

    def __init__(self,epochs,learning_rate,alpha):

        self.learning_rate = learning_rate
        self.epochs = epochs
        self.alpha = alpha
        self.m = None
        self.b = None

    def fit(self,x_train,y_train):

        self.coef_ = np.ones(x_train.shape[1])
        self.intercept_ = 0
        thetha = np.insert(self.coef_,0,self.intercept_)

        x_train = np.insert(x_train,0,1,axis=1)

        for i in range(self.epochs):

            thetha_der = np.dot(x_train.T,x_train).dot(thetha) - np.dot(x_train.T,y_train) + self.alpha*thetha

            thetha = thetha - self.learning_rate*thetha_der

        self.intercept_ = thetha[0]
        self.coef_ = thetha[1:]

    def predict(self,x_test):

        return np.dot(x_test,self.coef_) + self.intercept_

# %%
mg = MeraRidgeGD(epochs=500,learning_rate=0.005,alpha=0.001)

# %%
mg.fit(x_train,y_train)

# %%
y_pred = mg.predict(x_test)
print('R2_score :-',r2_score(y_test,y_pred))
print(mg.coef_)
print(mg.intercept_)
# Out:
# R2_score :- 0.4738018280260913
# [  46.65050914 -221.3750037   452.12080647  325.54248128  -29.09464178
#   -96.47517735 -190.90017011  146.32900372  400.80267299   95.09048094]
# 150.86975316713472
